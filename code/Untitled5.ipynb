# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation

fig, ax = plt.subplots()

x = np.arange(0, 2*np.pi, 0.01)
line, = ax.plot(x, np.sin(x))


def animate(i):
    line.set_ydata(np.sin(x + i / 50))  # update the data.
    return line,


ani = animation.FuncAnimation(
    fig, animate, interval=20, blit=True, save_count=50)


plt.show()

# %%
# To save the animation, use e.g.
#
#ani.save("movie.mp4")
#
# or
#
writer = animation.FFMpegWriter(
    fps=15, metadata=dict(artist='Me'), bitrate=1800)
ani.save("movie.mp4", writer=writer)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-bdaadc4cf277> in <module>
#       7 writer = animation.FFMpegWriter(
#       8     fps=15, metadata=dict(artist='Me'), bitrate=1800)
# ----> 9 ani.save("movie.mp4", writer=writer)
#
# ~\anaconda3\envs\base2\lib\site-packages\matplotlib\animation.py in save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1121         # callback a no-op; canvas.manager = None prevents resizing the GUI
#    1122         # widget (both are likewise done in savefig()).
# -> 1123         with mpl.rc_context({'savefig.bbox': None}), \
#    1124              writer.saving(self._fig, filename, dpi), \
#    1125              cbook._setattr_cm(self._fig.canvas,
#
# ~\anaconda3\envs\base2\lib\contextlib.py in __enter__(self)
#     111         del self.args, self.kwds, self.func
#     112         try:
# --> 113             return next(self.gen)
#     114         except StopIteration:
#     115             raise RuntimeError("generator didn't yield") from None
#
# ~\anaconda3\envs\base2\lib\site-packages\matplotlib\animation.py in saving(self, fig, outfile, dpi, *args, **kwargs)
#     247         """
#     248         # This particular sequence is what contextlib.contextmanager wants
# --> 249         self.setup(fig, outfile, dpi, *args, **kwargs)
#     250         try:
#     251             yield self
#
# ~\anaconda3\envs\base2\lib\site-packages\matplotlib\animation.py in setup(self, fig, outfile, dpi)
#     336         # Run here so that grab_frame() can write the data to a pipe. This
#     337         # eliminates the need for temp files.
# --> 338         self._run()
#     339
#     340     def _run(self):
#
# ~\anaconda3\envs\base2\lib\site-packages\matplotlib\animation.py in _run(self)
#     346                   cbook._pformat_subprocess(command))
#     347         PIPE = subprocess.PIPE
# --> 348         self._proc = subprocess.Popen(
#     349             command, stdin=PIPE, stdout=PIPE, stderr=PIPE,
#     350             creationflags=subprocess_creation_flags)
#
# ~\anaconda3\envs\base2\lib\subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     852                             encoding=encoding, errors=errors)
#     853
# --> 854             self._execute_child(args, executable, preexec_fn, close_fds,
#     855                                 pass_fds, cwd, env,
#     856                                 startupinfo, creationflags, shell,
#
# ~\anaconda3\envs\base2\lib\subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_start_new_session)
#    1305             # Start the process
#    1306             try:
# -> 1307                 hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#    1308                                          # no special security
#    1309                                          None, None,
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified

# %%
__figdir__ = '../plots_tom/' 
savefig_args = {'bbox_inches':'tight', 'pad_inches':0.2}
plotfiletype='png'

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation

fig, ax = plt.subplots()

x = np.arange(0, 2*np.pi, 0.01)
line, = ax.plot(x, np.sin(x))


for i in range(100):
    line.set_ydata(np.sin(x + i / 50))  # update the data.
    plt.savefig(__figdir__+'img'+ str(i) + '.' +plotfiletype,**savefig_args)

# %%
pwd
# Out:
# 'C:\\Users\\jtomf\\Documents\\Python\\S-MODE_analysis\\code'
